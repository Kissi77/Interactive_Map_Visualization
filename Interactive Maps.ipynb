# %%
pip install pandas

# %%
pip install folium

# %%
pip install geodatasets

# %%
pip install ipyleaflets

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# Load Natural Earth data through geodatasets
world = gpd.read_file(geodatasets.get_path("naturalearth.land"))

# Plot
world.plot()
plt.show()

# %%
import folium
m= folium.Map(location =[0,0], zoom_start=2)
m

# %%
def create_map(location, zoom_start=10):
  map_object=folium.Map(location=location, zoom_start=zoom_start)
  return map_object

# %%
  germany_map=create_map([51.1657, 10.4515], zoom_start=6)
  germany_map

# %%
germany_map.save("Germany_map.html")

# %%
from ipyleaflet import Map, TileLayer

m = Map(center=(0, 0), zoom=2)
topo_layer = TileLayer(
    url='https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png',
    attribution='Map data: &copy; <a href="https://opentopomap.org">OpenTopoMap</a> contributors'
)
m.add_layer(topo_layer)
m
